# %%
#1
word_1="python"
y="4"
z="Data"
m="science"
result=word_1 + y + z + m
print(result)
# Out:
# python4Datascience

# %%
course="Python 4 Data science"
print(course)
# Out:
# Python 4 Data science

# %%
len(course)
# Out:
# 21

# %%
x="company"
print(x.upper())
# Out:
# COMPANY

# %%
print(x.lower())
# Out:
# company

# %%
x="Python 4 Data science"
print(x.capitalize())
# Out:
# Python 4 data science

# %%
print(x.title())
# Out:
# Python 4 Data Science

# %%
print(x.swapcase())
# Out:
# pYTHON 4 dATA SCIENCE

# %%
y="Python 4 Data science"
print(y.startswith("Python"))
# Out:
# True

# %%
x="Python 4 Data science"
print(x.find("P",0))
# Out:
# 0

# %%
print(x.endswith("in"))
# Out:
# False

# %%
x="Python 4 Data science"
