# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to 'utf-8'.
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getitem__(self, key, /)
# ...

# %%
s="We cannot end the sentence with 'because',because 'because' is a conjuction."
print(s.capitalize())
# Out:
# We cannot end the sentence with 'because',because 'because' is a conjuction.

# %%
x=s.casefold()
print(x)
# Out:
# we cannot end the sentence with 'because',because 'because' is a conjuction.

# %%
s="We cannot end the sentence with 'because',because 'because' is a conjuction."
print(s.title())
# Out:
# We Cannot End The Sentence With 'Because',Because 'Because' Is A Conjuction.

# %%
s="We cannot end the sentence with 'because',because 'because' is a conjuction."
print(s.lower())
# Out:
# we cannot end the sentence with 'because',because 'because' is a conjuction.

# %%
s="We cannot end the sentence with 'because',because 'because' is a conjuction."
print(s.upper())
# Out:
# WE CANNOT END THE SENTENCE WITH 'BECAUSE',BECAUSE 'BECAUSE' IS A CONJUCTION.

# %%
s="We cannot End the Sentence with 'because',because 'because' is a Conjuction."
print(s.swapcase())
# Out:
# wE CANNOT eND THE sENTENCE WITH 'BECAUSE',BECAUSE 'BECAUSE' IS A cONJUCTION.

# %%
s="We cannot end the sentence with 'because',because 'because' is a conjuction."
print(s.count("t"))
# Out:
# 5

# %%
s="We cannot end the sentence with 'because',because 'because' is a conjuction."
print(s.startswith("W"))
# Out:
# True

# %%
s="We cannot end the sentence with 'because',because 'because' is a conjuction."
print(s.startswith("WIN"))
# Out:
# False

# %%
s="We cannot end the sentence with 'because',because 'because' is a conjuction."
print(s.endswith("ION"))
# Out:
# False

# %%
print(s.endswith("ion"))
# Out:
# False

# %%
print(s.find('t'))
# Out:
# 8

# %%
print(s.find('t',10))
# Out:
# 14

# %%
print(s.find('t',10,13))
# Out:
# -1

# %%
name='Arya'
age=11
s=f"my name is {name}.my age is {age}"
print(s)
# Out:
# my name is Arya.my age is 11

# %%
name='Arya'
age=11
s="my name is {}.my age is {}".format(name,age)
print(s)
# Out:
# my name is Arya.my age is 11

# %%
x='       manishashahi@gmai.com     '
print(x.strip())
# Out:
# manishashahi@gmai.com

# %%
x='ram->hari->sita'
print(x.split('->'))
# Out:
# ['ram', 'hari', 'sita']

# %%
x='ram->hari->sita'
print(x.split('->'))
